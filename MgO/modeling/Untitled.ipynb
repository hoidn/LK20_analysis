# %%
# %matplotlib notebook
# Out:
# /Users/oliver/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
from scipy.ndimage.filters import gaussian_filter as gfilt

# %% [markdown]
# ## Energy scales
#
# Mg binding energies (keV):
# K   1.30499995
# L1	0.063000001
# L2	0.0496000014
# L3	0.0491999984
#
# O binding energies:
# K	0.5431
# L 	0.0416

# %% [markdown]
# ## 2p ionization

# %%
xvals, m111, m200, m220, m333, m100_raw = np.genfromtxt('MgO_O2p.txt')

# %%
[plt.plot(xvals, m) for m in [m111, m200, m220]]
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
[plt.plot(xvals, m) for m in [m100_raw]]
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
def plot_progression(filename, width = 5):
    xvals, m111, m200, m220, m333, m100_raw = np.genfromtxt(filename)

# %%
import scipy
def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

# %%
from scipy.interpolate import interp1d

# %%
interp1d?

# %%
def pulse_profile(width):
    #x = np.arange(-width, width, 1.)
    x = np.arange(0, 2 * width, width + 1.)
    full_gaussian = gaussian(x, width, width)
    interpolator = interp1d(x - width, full_gaussian, fill_value = 0.)
    return interpolator

# %%
p = pulse_profile(5)

# %%
x = np.arange(0, 101, 1.)

# %%
plt.plot(x, p(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-cdf0e57fc952> in <module>()
# ----> 1 plt.plot(x, p(x))
#
# /Users/oliver/anaconda2/lib/python2.7/site-packages/scipy/interpolate/polyint.pyc in __call__(self, x)
#      78         """
#      79         x, x_shape = self._prepare_x(x)
# ---> 80         y = self._evaluate(x)
#      81         return self._finish_y(y, x_shape)
#      82
#
# /Users/oliver/anaconda2/lib/python2.7/site-packages/scipy/interpolate/interpolate.pyc in _evaluate(self, x_new)
#     588         y_new = self._call(self, x_new)
#     589         if not self._extrapolate:
# --> 590             below_bounds, above_bounds = self._check_bounds(x_new)
#     591             if len(y_new) > 0:
#     592                 # Note fill_value must be broadcast up to the proper size
#
# ...
